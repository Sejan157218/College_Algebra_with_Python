# %% [markdown]
# # Setup up a Proportion:
#  n1/d1 = n2/d2

# %%
n1 = 22
d1 = 10
n2 = 0
d2 = 12

#put zero for unknown value

if n2 == 0:
  answer = n1 * d2 /d1
  print("answer" , answer)

if d2 == 0:
  answer = n2 * d1 / n1
  print("answer" , answer)
# Out:
# answer 26.4
