# %%
import matplotlib.pyplot as plt
import numpy as np



xmin = 0
xmax = 10
ymin = 0
ymax = 150

x1 = 0
x2 = 2
y1 = 55
y2 = 76

m = (y2-y1) / (x2 - x1)

b = y1 - m * x1
y = m * 6 + b
y3 = m * xmin + b
y4 =  m * xmax + b
print("m = ", m, "b = ", b, "y = ", y)

fig, ax = plt.subplots()
ax.grid(True)
ax.set_xlabel("time")
ax.set_xlabel("Population")
# ax.set_xticks(np.arange(xmin,xmax,2))
# ax.set_yticks(np.arange(ymin,ymax,2))

# plt.axis([xmin, xmax, ymin,ymax])
# plt.plot([xmin, xmax], [0,0], 'b')
# plt.plot([0,0],[ymin, ymax], 'b')
plt.axis([xmin, xmax, ymin, ymax])
plt.plot([xmin, xmax], [y3,y4], 'b')
plt.plot([6], [y], 'ro', label='point')

plt.show()
# Out:
# m =  10.5 b =  55.0 y =  118.0
