# %%
numerator = 12
denominator = 24
factor = 1

for test_factor in range(1,denominator+1):
  if numerator%test_factor==0 and denominator%test_factor==0:
    factor = test_factor
n = int(numerator/factor)
d = int(denominator/factor)

print("original: ", numerator, "/", denominator)
print("reduced: ", n, "/", d)
# Out:
# original:  12 / 24
# reduced:  1 / 2

# %% [markdown]
# # You can add this code to the decimal-to-fraction code

# %%
digit = input("input a decimal number", )

exponent = int(len(digit))-1

n = float(digit)
numerator = int(n*10**exponent)
denominator = 10 ** exponent
factor = 1

for test_factor in range(1, denominator+1):
  if numerator%test_factor==0 and denominator%test_factor==0:
    factor = test_factor

n = int(numerator/factor)
d = int(denominator/factor)
print("The decimal is ", n)
print("The fraction is ", n, "/", d)
print("exponent", exponent, 'n', n, "numerator", numerator, "denominator", denominator, "percent")
# Out:
# input a decimal number.4444
# The decimal is  1111
# The fraction is  1111 / 2500
# exponent 4 n 1111 numerator 4444 denominator 10000 percent

# %%
import math

n = 12

upper_limit = math.floor(math.sqrt(n)) + 1

# Find square factors
for maybe_factor in range(1,upper_limit):
    if n % (maybe_factor**2) == 0:
        max_factor = maybe_factor
print("n = ", n)
print("Square rooted factor = ", max_factor)
print("Square factor = ", max_factor**2)
print("integer: ", n/(max_factor**2))
print("upper_limit", upper_limit, math.sqrt(n))
# Out:
# n =  12
# Square rooted factor =  2
# Square factor =  4
# integer:  3.0
# upper_limit 4 3.4641016151377544

# %%
import sympy
import math
from sympy import symbols

n = 24

upper_limit = math.floor(math.sqrt(n)) + 1

max_factor = 1
other_factor = 1
square_root = 1

for test_factor in range(1, upper_limit):
  if n%(test_factor**2)==0:
    max_factor = test_factor

other_factor = n/max_factor
square_root = int(math.sqrt(max_factor))
other_factor =int(other_factor)
output = square_root*sympy.sqrt(other_factor)
print("max_factor", max_factor, "other_factor", other_factor, "square_root", square_root, "output", output)
output
# Out:
# max_factor 2 other_factor 12 square_root 1 output 2*sqrt(3)
# 2*sqrt(3)
